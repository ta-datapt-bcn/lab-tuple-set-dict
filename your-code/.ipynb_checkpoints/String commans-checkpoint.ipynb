# %%
import re

# %%
word='abcdefghijklmnopqrstuvwxyz'
len(word)
# Out:
# 26

# %%
word[0]
# Out:
# 'a'

# %%
word[-1]
# Out:
# 'z'

# %%
x='Buenas'
y='Tardes'

# %%
z=[x,y]

# %%
print(z)
# Out:
# ['Buenas', 'Tardes']

# %%
' '.join(z)
# Out:
# 'Buenas Tardes'
